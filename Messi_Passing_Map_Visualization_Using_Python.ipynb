# %% [markdown]
# <a href="https://colab.research.google.com/github/strng-fer/DataBelajar/blob/main/Messi_Passing_Map_Visualization_Using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mplsoccer.pitch import Pitch

# %% [markdown]
# #Gathering Data

# %%
df = pd.read_csv('/content/messibetis.csv')
df()
# Out:
#    player  minute  second    x    y  type       outcome  endX  endY
# 0   messi      45       0   50   50  Pass    Successful    40    43
# 1   messi      45      25   63   48  Pass    Successful    75    83
# 2   messi      46       4   74   58  Pass    Successful    71    65
# 3   messi      46       7   76   68  Pass    Successful    95    78
# 4   messi      46      55  100    1  Pass  Unsuccessful    96    38
# 5   messi      47      42   73   25  Pass    Successful    70    54
# 6   messi      49      47   75   43  Pass  Unsuccessful    82    38
# 7   messi      50      10   79   31  Pass    Successful    87    24
# 8   messi      50      17   82   52  Pass    Successful    93    68
# 9   messi      50      24   98   62  Pass  Unsuccessful    98    61
# 10  messi      55      22   30   12  Pass    Successful    22    24
# 11  messi      56      24   38   42  Pass    Successful    37    51
# 12  messi      56      36   53   44  Pass    Successful    43    62
# ...

# %% [markdown]
# # Data Manipulation

# %%
df['x']=df['x']*1.2
df['y']=df['y']*.8
df['endX']=df['endX']*1.2
df['endY']=df['endY']*.8

# %%
df.head()
# Out:
#   player  minute  second       x     y  type       outcome   endX  endY
# 0  messi      45       0   72.00  40.0  Pass    Successful   48.0  34.4
# 1  messi      45      25   90.72  38.4  Pass    Successful   90.0  66.4
# 2  messi      46       4  106.56  46.4  Pass    Successful   85.2  52.0
# 3  messi      46       7  109.44  54.4  Pass    Successful  114.0  62.4
# 4  messi      46      55  144.00   0.8  Pass  Unsuccessful  115.2  30.4

# %% [markdown]
# # Visualization

# %%
fig = plt.figure(figsize=(13.5, 8))
fig.set_facecolor('Black')

pitch = Pitch(pitch_type='statsbomb', pitch_color='Lightgreen', line_color='White')
ax = fig.add_subplot(1, 1, 1)
pitch.draw(ax=ax)
plt.gca().invert_yaxis()

for i, row in df.iterrows():
    if row['outcome'] == 'Successful':
        plt.plot([row['x'], row['endX']], [row['y'], row['endY']], color='green')
        plt.scatter(row['x'], row['y'], color='green')
    elif row['outcome'] == 'Unsuccessful':
        plt.plot([row['x'], row['endX']], [row['y'], row['endY']], color='red')
        plt.scatter(row['x'], row['y'], color='red')

plt.title('Messi Pass Map vs Real Betis', color='white', size=20)
plt.show()
